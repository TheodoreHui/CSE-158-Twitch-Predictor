# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import defaultdict

# %%
twitch_little_data = pd.read_csv('100k_a.csv')

# %%
twitch_little_data['time_start'] *= 10 
twitch_little_data['time_stop'] *= 10 

twitch_little_data['time_watched'] = (twitch_little_data['time_stop'] - twitch_little_data['time_start'])

twitch_little_data['relative_time_start'] = twitch_little_data['time_start'] % (24*60)
twitch_little_data['relative_time_stop'] = twitch_little_data['time_stop'] % (24*60)

twitch_little_data['relative_hour_start'] = twitch_little_data['relative_time_start']  // 60
twitch_little_data['relative_hour_stop'] = twitch_little_data['relative_time_stop']  // 60

twitch_little_data['day_start'] = twitch_little_data['time_start'] // (24*60)
twitch_little_data['day_stop'] = twitch_little_data['time_stop'] // (24*60)

twitch_little_data['week_start'] = twitch_little_data['day_start'] % 7 + 1
twitch_little_data['week_stop'] = twitch_little_data['day_stop'] % 7 + 1

# %%
# twitch_little_data.head();

# %% [markdown]
# ## Basic Exploration

# %%
num_interactions = twitch_little_data.shape[0]
num_unique_users = twitch_little_data['user_id'].nunique()
num_unique_streamers = twitch_little_data['streamer_username'].nunique()

num_interactions, num_unique_users, num_unique_streamers
# Out:
# (1048575, 34611, 86683)

# %% [markdown]
# ## Distribution of watch time

# %%
sns.histplot(twitch_little_data, x = 'time_watched', bins=20, stat= 'probability')
twitch_little_data['time_watched'].describe()
# Out:
# count    1.048575e+06
# mean     3.126626e+01
# std      4.218047e+01
# min      1.000000e+01
# 25%      1.000000e+01
# 50%      1.000000e+01
# 75%      3.000000e+01
# max      9.000000e+02
# Name: time_watched, dtype: float64

# %% [markdown]
# ## Distribution of number of unique streamers watched by viewers

# %%
twitch_streamer_per_user = twitch_little_data[['user_id', 'streamer_username']].groupby('user_id').apply(lambda x : len(np.unique(x)))
plt.figure(figsize=(25, 10), dpi=80)
fig, axs = plt.subplots(nrows=2, sharex=True)
sns.boxplot(x=twitch_streamer_per_user, fliersize = 1, ax=axs[0])
fig_kde = sns.kdeplot(twitch_streamer_per_user, ax = axs[1])
fig_kde.set(xlabel='Unique Streamers Watched', ylabel='Probability', title='Distribution of Unique Streamers Watched')
fig.set(figheight=10, figwidth=16)
# Out:
# [None, None]

# %% [markdown]
# ## Distribution of the proportion of watchtime by percentile

# %%
total_watchtime = twitch_little_data['time_watched'].sum()
streamer_watchtime = twitch_little_data[['time_watched', 'streamer_username']].groupby('streamer_username').sum().sort_values('time_watched', ascending=False)
prop_of_total_watchtime = (streamer_watchtime/total_watchtime).reset_index()

prop_of_total_watchtime['percentile'] = 1 + prop_of_total_watchtime.index * 100 // prop_of_total_watchtime.shape[0]
prop_of_total_watchtime = prop_of_total_watchtime[['percentile', 'time_watched']].groupby('percentile').sum().reset_index()

plt.figure(figsize=(25, 5), dpi=80)

ax = sns.barplot(prop_of_total_watchtime, x='percentile', y='time_watched')
ax.set(ylabel='Proportion of Total Watchtime', xlabel='Percentile', title='Distibution of Watchtime by Popularity Percentile')

prop_of_total_watchtime
# Out:
#     percentile  time_watched
# 0            1      0.528916
# 1            2      0.102670
# 2            3      0.059347
# 3            4      0.039966
# 4            5      0.029506
# ..         ...           ...
# 95          96      0.000264
# 96          97      0.000264
# 97          98      0.000264
# 98          99      0.000264
# 99         100      0.000264
#
# [100 rows x 2 columns]

# %%
sns.histplot(twitch_little_data, x = 'relative_time_start', stat = 'probability')
# Out:
# <AxesSubplot:xlabel='relative_time_start', ylabel='Probability'>

# %% [markdown]
# ## Distribution of watchtime by hour

# %%
fig = sns.histplot(twitch_little_data, x = 'relative_hour_start', stat = 'probability', discrete = True, alpha=0.5); 
# fig = sns.histplot(twitch_little_data, x = 'relative_hour_stop', stat = 'probability', discrete = True, alpha=0.5, label="End Hour"); 
fig.set(ylabel='Probability of Watching', xlabel ='Hour', title='Distribution of Watching Twitch V.S. Hour')
# Out:
# [Text(0, 0.5, 'Probability of Watching'),
#  Text(0.5, 0, 'Hour'),
#  Text(0.5, 1.0, 'Distribution of Watching Twitch V.S. Hour')]

# %%
fig = sns.histplot(twitch_little_data, x = 'day_start', discrete=True, stat='probability')
fig.set(ylabel='Probability of Watching', xlabel ='Day', title='Distribution of Watching Twitch V.S. Days')
# Out:
# [Text(0, 0.5, 'Probability of Watching'),
#  Text(0.5, 0, 'Day'),
#  Text(0.5, 1.0, 'Distribution of Watching Twitch V.S. Days')]

# %%
sns.histplot(twitch_little_data, x = 'week_start', stat = 'probability', discrete = True);

# %% [markdown]
# # Predictive

# %% [markdown]
# ## Baseline

# %%
concurrent_viewers = defaultdict(lambda: defaultdict(int))
for index, row in twitch_little_data.iterrows():
    start_time, stop_time, streamer = row['time_start'], row['time_stop'], row['streamer_username']
    for time in range(start_time, stop_time+1, 10):
        concurrent_viewers[time][streamer] += 1
most_viewed_streamer = {time:max(dictionary, key=dictionary.get) for time, dictionary in  concurrent_viewers.items()}

# %%
most_viewed_streamer
# Out:
# {1540: 'shroud',
#  1550: 'shroud',
#  1560: 'shroud',
#  1660: 'tfue',
#  1670: 'tfue',
#  1680: 'tfue',
#  1690: 'shroud',
#  5870: 'tfue',
#  5880: 'tfue',
#  5890: 'tfue',
#  5900: 'tfue',
#  5910: 'tfue',
#  5920: 'tfue',
#  5930: 'tfue',
#  5940: 'tfue',
#  7340: 'tfue',
#  7350: 'tfue',
#  7360: 'tfue',
#  7370: 'tfue',
#  10210: 'tfue',
#  10220: 'tfue',
#  10230: 'tfue',
#  10240: 'tfue',
#  10250: 'ninja',
#  10260: 'tfue',
#  10270: 'tfue',
#  10280: 'tfue',
#  10290: 'tfue',
#  10300: 'tfue',
#  10310: 'tfue',
#  10320: 'tfue',
#  10330: 'tfue',
#  10340: 'tfue',
#  10350: 'tfue',
#  10360: 'tfue',
#  11650: 'ninja',
#  11660: 'drdisrespect',
#  11670: 'drdisrespect',
#  12950: 'timthetatman',
#  12960: 'timthetatman',
#  12970: 'timthetatman',
#  24580: 'squeezielive',
#  24590: 'squeezielive',
#  24540: 'squeezielive',
#  24550: 'squeezielive',
#  24560: 'squeezielive',
#  26010: 'overwatchleague',
#  26020: 'overwatchleague',
#  26030: 'overwatchleague',
#  26040: 'overwatchleague',
#  26000: 'overwatchleague',
#  26050: 'overwatchleague',
#  34590: 'asmongold',
#  34600: 'asmongold',
#  36000: 'tfue',
#  36010: 'tfue',
#  37390: 'tfue',
#  37400: 'tfue',
#  37410: 'tfue',
#  37420: 'tfue',
#  37430: 'tfue',
#  37550: 'asmongold',
#  37560: 'asmongold',
#  37570: 'tfue',
#  37580: 'tfue',
#  37590: 'shroud',
#  37600: 'tsm_bjergsen',
#  38740: 'gotaga',
#  38750: 'gotaga',
#  38720: 'gotaga',
#  38730: 'gotaga',
#  40530: 'cloakzy',
#  40540: 'cloakzy',
#  42040: 'symfuhny',
#  42050: 'symfuhny',
#  43150: 'ninja',
#  43160: 'ninja',
#  43140: 'ninja',
#  43270: 'warframe',
#  43280: 'warframe',
#  44760: 'tfue',
#  44770: 'tfue',
#  44780: 'tfue',
#  44740: 'tfue',
#  44750: 'tfue',
#  46020: 'tfue',
#  46030: 'tfue',
#  46040: 'tfue',
#  47510: 'tfue',
#  47520: 'tfue',
#  48590: 'ninja',
#  48600: 'ninja',
#  48670: 'ninja',
#  48680: 'ninja',
#  48650: 'ninja',
#  48660: 'ninja',
#  50440: 'asmongold',
#  50450: 'asmongold',
#  50460: 'asmongold',
#  50470: 'callofduty',
#  50480: 'pokemon',
#  50490: 'pokemon',
#  50430: 'asmongold',
#  51950: 'tfue',
#  51960: 'tfue',
#  51970: 'tfue',
#  51980: 'yoda',
#  51990: 'tfue',
#  52080: 'tfue',
#  52090: 'tfue',
#  53220: 'cloud9',
#  53230: 'nickmercs',
#  53240: 'nickmercs',
#  53060: 'nickmercs',
#  53070: 'zerator',
#  53080: 'zerator',
#  53090: 'zerator',
#  53100: 'dreamhackcs',
#  53110: 'dreamhackcs',
#  53120: 'dreamhackcs',
#  53130: 'dreamhackcs',
#  53140: 'dreamhackcs',
#  53270: 'couragejd',
#  53280: 'dreamhackcs',
#  53290: 'dreamhackcs',
#  53300: 'dreamhackcs',
#  53310: 'dreamhackcs',
#  53250: 'nickmercs',
#  53260: 'nickmercs',
#  54150: 'ninja',
#  54160: 'ninja',
#  54170: 'ninja',
#  54180: 'ninja',
#  54190: 'ninja',
#  54740: 'tfue',
#  54750: 'ninja',
#  54760: 'ninja',
#  54770: 'ninja',
#  54780: 'tfue',
#  54790: 'tfue',
#  54800: 'tfue',
#  54810: 'tfue',
#  57360: 'tfue',
#  57370: 'tfue',
#  57380: 'dreamhackcs',
#  57390: 'dreamhackcs',
#  57400: 'dreamhackcs',
#  57410: 'tfue',
#  57420: 'tfue',
#  57430: 'riotgames',
#  58690: 'gotaga',
#  58700: 'gotaga',
#  58980: 'asmongold',
#  58990: 'asmongold',
#  60240: 'asmongold',
#  60250: 'asmongold',
#  580: 'nickmercs',
#  590: 'nickmercs',
#  1170: 'cohhcarnage',
#  1180: 'cohhcarnage',
#  1190: 'cohhcarnage',
#  2060: 'aydan',
#  2070: 'aydan',
#  5190: 'playhearthstone',
#  5200: 'playhearthstone',
#  5210: 'playhearthstone',
#  5220: 'playhearthstone',
#  5230: 'playhearthstone',
#  5240: 'playhearthstone',
#  9220: 'shroud',
#  9230: 'shroud',
#  9240: 'shroud',
#  10960: 'dakotaz',
#  10970: 'lck_korea',
#  13440: 'tfue',
#  13450: 'tfue',
#  13950: 'tfblade',
#  13960: 'tfblade',
#  13970: 'esl_csgo',
#  13980: 'esl_csgo',
#  14100: 'callofduty',
#  14110: 'mjchino',
#  15310: 'esl_csgo',
#  15320: 'esl_csgo',
#  15330: 'esl_csgo',
#  15370: 'esl_csgo',
#  15380: 'esl_csgo',
#  16520: 'esl_csgo',
#  16530: 'tsm_hamlinz',
#  16660: 'esl_csgo',
#  16670: 'esl_csgo',
#  21220: 'dakotaz',
#  21230: 'godjj',
#  25590: 'ninja',
#  25600: 'ninja',
#  25610: 'ninja',
#  25620: 'ninja',
#  25630: 'ninja',
#  25640: 'ninja',
#  25650: 'ninja',
#  25660: 'ninja',
#  25670: 'ninja',
#  25680: 'ninja',
#  26230: 'shroud',
#  26240: 'aydan',
#  26980: 'alexelcapo',
#  26990: 'alexelcapo',
#  27780: 'tsm_hamlinz',
#  27790: 'tsm_hamlinz',
#  27800: 'tsm_hamlinz',
#  28370: 'riotgames',
#  28380: 'riotgames',
#  28390: 'riotgames',
#  28400: 'riotgames',
#  29320: 'shroud',
#  29330: 'shroud',
#  29880: 'riotgames',
#  29890: 'riotgames',
#  31320: 'ninja',
#  31330: 'ninja',
#  31340: 'ninja',
#  36440: 'tfue',
#  36450: 'tfue',
#  38290: 'dakotaz',
#  38300: 'sodapoppin',
#  41300: 'ninja',
#  41310: 'ninja',
#  42800: 'ninja',
#  42810: 'ninja',
#  43910: 'faker',
#  43920: 'faker',
#  45560: 'dakotaz',
#  45570: 'dakotaz',
#  46640: 'summit1g',
#  46650: 'summit1g',
#  46660: 'summit1g',
#  48620: 'ninja',
#  48630: 'ninja',
#  48640: 'ninja',
#  48690: 'ninja',
#  48700: 'ninja',
#  48710: 'ninja',
#  56270: 'fortnite',
#  56280: 'pokimane',
#  56260: 'fortnite',
#  56510: 'shroud',
#  56520: 'shroud',
#  56530: 'shroud',
#  56540: 'shroud',
#  59830: 'ninja',
#  59840: 'ninja',
#  59850: 'handongsuk',
#  59860: 'handongsuk',
#  1350: 'esl_csgo',
#  1360: 'naru',
#  4100: 'ninja',
#  4110: 'ninja',
#  7120: 'ninja',
#  7130: 'ninja',
#  8430: 'greekgodx',
#  8440: 'iamtrevormay',
#  8450: 'ninja',
#  9930: 'ninja',
#  9940: 'ninja',
#  9950: 'ninja',
#  9960: 'iwilldominate',
#  9900: 'tfblade',
#  9910: 'tfblade',
#  9920: 'ninja',
#  11440: 'ninja',
#  11450: 'ninja',
#  22900: 'ghostrecon',
#  22910: 'ghostrecon',
#  25780: 'ninja',
#  25790: 'ninja',
#  44520: 'ninja',
#  44530: 'ninja',
#  46840: 'thijs',
#  46850: 'thijs',
#  47090: 'symfuhny',
#  47100: 'faker',
#  47110: 'asiagodtonegg3be0',
#  47120: 'asiagodtonegg3be0',
#  47130: 'faker',
#  47140: 'faker',
#  47380: 'ninja',
#  47390: 'beasttrollmc',
#  50250: 'zerator',
#  50260: 'zerator',
#  51810: 'nickmercs',
#  51820: 'nickmercs',
#  55790: 'ninja',
#  55800: 'ninja',
#  57210: 'mongraal',
#  57220: 'mongraal',
#  57230: 'mongraal',
#  57240: 'mongraal',
#  57250: 'dreamhackcs',
#  57260: 'dreamhackcs',
#  57270: 'dreamhackcs',
#  57280: 'dreamhackcs',
#  1420: 'timthetatman',
#  1430: 'mrsavage',
#  1460: 'timthetatman',
#  1470: 'gafallen',
#  2940: 'ninja',
#  2950: 'ninja',
#  4460: 'tfue',
#  4470: 'tfue',
#  7030: 'ninja',
#  7040: 'ruvelius',
#  8670: 'gotaga',
#  8680: 'gotaga',
#  8660: 'gotaga',
#  9860: 'ninja',
#  9870: 'ninja',
#  10130: 'ninja',
#  10140: 'ninja',
#  10750: 'esl_csgo',
#  10760: 'esl_csgo',
#  10770: 'esl_csgo',
#  11070: 'dakotaz',
#  11080: 'dakotaz',
#  11290: 'riotgames',
#  11300: 'riotgames',
#  11310: 'riotgames',
#  11320: 'riotgames',
#  11330: 'riotgames',
#  11340: 'riotgames',
#  11430: 'admiralbahroo',
#  12680: 'riotgames',
#  12690: 'timthetatman',
#  12700: 'timthetatman',
#  12940: 'squeezielive',
#  12980: 'squeezielive',
#  14240: 'timthetatman',
#  14250: 'timthetatman',
#  14260: 'yassuo',
#  14390: 'ninja',
#  14400: 'ninja',
#  17240: 'tfue',
#  17250: 'ninja',
#  15970: 'tfue',
#  15980: 'tfue',
#  15990: 'tfue',
#  17300: 'tfblade',
#  17310: 'rocketleague',
#  18780: 'ninja',
#  18790: 'ninja',
#  18710: 'ninja',
#  18720: 'blacdadon2k',
#  20210: 'ninja',
#  20220: 'ninja',
#  21620: 'ninja',
#  21630: 'ninja',
#  22470: 'gotaga',
#  22480: 'dakotaz',
#  22630: '10000days',
#  22640: 'ninja',
#  22650: 'ninja',
#  22810: 'ninja',
#  22820: 'ninja',
#  22850: 'ninja',
#  22860: 'ninja',
#  24530: 'squeezielive',
#  24690: 'nickmercs',
#  24700: 'nickmercs',
#  24470: 'ninja',
#  24480: 'ninja',
#  24440: 'ninja',
#  24450: 'ninja',
#  25700: 'ninja',
#  25710: 'ninja',
#  25720: 'ninja',
#  25730: 'ninja',
#  25930: 'overwatchleague',
#  25940: 'overwatchleague',
#  25950: 'overwatchleague',
#  25960: 'overwatchleague',
#  25970: 'overwatchleague',
#  25980: 'overwatchleague',
#  25990: 'overwatchleague',
#  27000: 'script',
#  27010: 'script',
#  27150: 'montanablack88',
#  27160: 'montanablack88',
#  29620: 'riotgames',
#  29630: 'riotgames',
#  30060: 'alanzoka',
#  30070: 'ninja',
#  30220: 'ninja',
#  30230: 'ninja',
#  32810: 'ninja',
#  32820: 'ninja',
#  32790: 'timthetatman',
#  32800: 'timthetatman',
#  32930: 'ninja',
#  32940: 'ninja',
#  32950: 'ninja',
#  32980: 'ninja',
#  32990: 'ninja',
#  34290: 'castro_1021',
#  34300: 'castro_1021',
#  34250: 'ninja',
#  34260: 'ninja',
#  34430: 'asmongold',
#  34440: 'asmongold',
#  34610: 'asmongold',
#  34620: 'asmongold',
#  34630: 'tfue',
#  36060: 'tfue',
#  36070: 'tfue',
#  36080: 'tfue',
#  36090: 'tfue',
#  36100: 'tfue',
#  36110: 'tfue',
#  36120: 'tfue',
#  36130: 'tfue',
#  38850: 'gotaga',
#  38860: 'ninja',
#  38830: 'ninja',
#  38840: 'gotaga',
#  40280: 'asmongold',
#  40290: 'asmongold',
#  41360: 'ninja',
#  41370: 'ninja',
#  44250: 'ninja',
#  44260: 'ninja',
#  44270: 'ninja',
#  44280: 'ninja',
#  44290: 'ninja',
#  160: 'tfue',
#  170: 'tfue',
#  180: 'tfue',
#  190: 'tfue',
#  200: 'tfue',
#  210: 'tfue',
#  2710: 'timthetatman',
#  2720: 'timthetatman',
#  2730: 'timthetatman',
#  2740: 'timthetatman',
#  2750: 'timthetatman',
#  2760: 'ninja',
#  2770: 'ninja',
#  2780: 'ninja',
#  32860: 'ninja',
#  32870: 'ninja',
#  35950: 'tfue',
#  35960: 'tfue',
#  57130: 'faker',
#  57140: 'faker',
#  57150: 'faker',
#  59990: 'faker',
#  60000: 'faker',
#  60080: 'hardgamechannel',
#  60090: 'hardgamechannel',
#  60100: 'sodapoppin',
#  25330: 'riotgames',
#  25340: 'riotgames',
#  25450: 'symfuhny',
#  25460: 'back2warcraft',
#  37010: 'sodapoppin',
#  37020: 'sodapoppin',
#  37030: 'sodapoppin',
#  37040: 'sodapoppin',
#  37050: 'sodapoppin',
#  37140: 'trymacs',
#  37150: 'trymacs',
#  36980: 'mister903',
#  36990: 'mister903',
#  37000: 'sodapoppin',
#  37100: 'trymacs',
#  37110: 'trymacs',
#  38310: 'sodapoppin',
#  38410: 'sodapoppin',
#  38420: 'sodapoppin',
#  38430: 'sodapoppin',
#  38440: 'sodapoppin',
#  38450: 'sodapoppin',
#  38460: 'sodapoppin',
#  38470: 'sodapoppin',
#  38480: 'sodapoppin',
#  38490: 'sodapoppin',
#  38500: 'sodapoppin',
#  38510: 'ninja',
#  38520: 'ninja',
#  39290: 'tsm_hamlinz',
#  39300: 'tsm_hamlinz',
#  39310: 'tsm_hamlinz',
#  39320: 'tsm_hamlinz',
#  39330: 'tsm_hamlinz',
#  39340: 'tsm_hamlinz',
#  39350: 'tsm_hamlinz',
#  39360: 'tsm_hamlinz',
#  39650: 'dakotaz',
#  39660: 'dakotaz',
#  39670: 'dakotaz',
#  39680: 'dakotaz',
#  39910: 'ninja',
#  39920: 'ninja',
#  39930: 'ninja',
#  40360: 'asmongold',
#  40370: 'asmongold',
#  40380: 'asmongold',
#  41040: 'dakotaz',
#  41050: 'dakotaz',
#  41060: 'godjj',
#  41070: 'dakotaz',
#  41080: 'dakotaz',
#  41090: 'dakotaz',
#  41100: 'dakotaz',
#  41110: 'dakotaz',
#  41120: 'jinnytty',
#  41130: 'jinnytty',
#  41140: 'dakotaz',
#  41150: 'dakotaz',
#  41160: 'dakotaz',
#  41170: 'dakotaz',
#  41180: 'dakotaz',
#  41190: 'thijs',
#  41200: 'dakotaz',
#  41210: 'dakotaz',
#  41220: 'ninja',
#  41230: 'ninja',
#  41240: 'ninja',
#  41340: 'ninja',
#  41350: 'ninja',
#  41380: 'ninja',
#  42170: 'yoda',
#  42180: 'yoda',
#  42190: 'yoda',
#  42200: 'yoda',
#  42210: 'yoda',
#  42220: 'symfuhny',
#  42230: 'symfuhny',
#  42240: 'yoda',
#  42250: 'symfuhny',
#  42260: 'esl_csgo',
#  42270: 'esl_csgo',
#  42280: 'esl_csgo',
#  42290: 'symfuhny',
#  42300: 'symfuhny',
#  42310: 'symfuhny',
#  42320: 'symfuhny',
#  42330: 'symfuhny',
#  42340: 'symfuhny',
#  42350: 'esl_csgo',
#  42360: 'esl_csgo',
#  42370: 'sodapoppin',
#  42380: 'esl_csgo',
#  42390: 'esl_csgo',
#  42400: 'esl_csgo',
#  42780: 'thijs',
#  42790: 'ninja',
#  42820: 'sodapoppin',
#  42830: 'ninja',
#  42840: 'ninja',
#  42850: 'ninja',
#  42860: 'ninja',
#  42870: 'ninja',
#  42880: 'ninja',
#  42890: 'ninja',
#  42900: 'ninja',
#  42910: 'asmongold',
#  42920: 'asmongold',
#  42750: 'ninja',
#  42760: 'ninja',
#  42770: 'thijs',
#  43670: 'faker',
#  43680: 'faker',
#  44410: 'ninja',
#  44420: 'ninja',
#  44430: 'ninja',
#  44970: 'tfue',
#  44980: 'tfue',
#  44990: 'tfue',
#  45140: 'summit1g',
#  45150: 'c9sneaky',
#  45160: 'c9sneaky',
#  45470: 'faker',
#  45480: 'dakotaz',
#  46920: 'dota2ruhub',
#  46930: 'dota2ruhub',
#  46940: 'inecr7024',
#  46950: 'dota2ruhub',
#  46960: 'dota2ruhub',
#  46970: 'dota2ruhub',
#  46980: 'dota2ruhub',
#  46990: 'dota2ruhub',
#  47000: 'dota2ruhub',
#  47010: 'dota2ruhub',
#  47020: 'dota2ruhub',
#  47030: 'dota2ruhub',
#  47040: 'dota2ruhub',
#  47050: 'dota2ruhub',
#  47060: 'amarcodtv',
#  47070: 'symfuhny',
#  47080: 'symfuhny',
#  47150: 'symfuhny',
#  47160: 'symfuhny',
#  47170: 'ninja',
#  47180: 'ninja',
#  47190: 'ninja',
#  49360: 'tsm_hamlinz',
#  49370: 'tsm_hamlinz',
#  49380: 'tsm_hamlinz',
#  49390: 'tsm_hamlinz',
#  50520: 'arigameplays',
#  50530: 'symfuhny',
#  50630: 'jukes',
#  50640: 'jukes',
#  50650: 'tsm_hamlinz',
#  50660: 'tsm_hamlinz',
#  50670: 'tsm_hamlinz',
#  50680: 'tsm_hamlinz',
#  50690: 'jukes',
#  50700: 'tsm_hamlinz',
#  50710: 'jukes',
#  50720: 'tsm_hamlinz',
#  50730: 'tsm_hamlinz',
#  50740: 'tsm_hamlinz',
#  50750: 'tsm_hamlinz',
#  50760: 'tsm_hamlinz',
#  50770: 'tsm_hamlinz',
#  50780: 'tsm_hamlinz',
#  50790: 'tsm_hamlinz',
#  50800: 'tsm_hamlinz',
#  50810: 'xbt306x',
#  50820: 'pokimane',
#  50830: 'pokimane',
#  50840: 'pokimane',
#  50850: 'pokimane',
#  50860: 'loltyler1',
#  51110: 'beyou0728',
#  51120: 'dakotaz',
#  51130: 'dakotaz',
#  51140: 'dakotaz',
#  51150: 'lebouseuh',
#  52550: 'dakotaz',
#  52560: 'dakotaz',
#  52570: 'dakotaz',
#  52580: 'dakotaz',
#  52590: 'dakotaz',
#  52600: 'dakotaz',
#  52610: 'dakotaz',
#  52620: 'dakotaz',
#  53910: 'playhearthstone',
#  53920: 'dota2ruhub',
#  53930: 'dota2ruhub',
#  54330: 'ninja',
#  54340: 'ninja',
#  55170: 'shroud',
#  55180: 'shroud',
#  55190: 'shroud',
#  55320: 'godjj',
#  55330: 'godjj',
#  55200: 'shroud',
#  55210: 'shroud',
#  55220: 'shroud',
#  55230: 'admiralbulldog',
#  55560: 'jovirone',
#  55570: 'jovirone',
#  55580: 'jovirone',
#  55590: 'faker',
#  55600: 'faker',
#  56400: 'shroud',
#  56410: 'shroud',
#  56420: 'shroud',
#  56430: 'shroud',
#  56440: 'shroud',
#  56450: 'shroud',
#  56460: 'tsm_hamlinz',
#  56470: 'tsm_hamlinz',
#  56480: 'tsm_hamlinz',
#  56490: 'shroud',
#  56500: 'shroud',
#  56550: 'iceyicetv',
#  56560: 'iceyicetv',
#  56570: 'iceyicetv',
#  56580: 'iceyicetv',
#  56590: 'nl_kripp',
#  56600: 'iceyicetv',
#  56610: 'nl_kripp',
#  56620: 'admiralbulldog',
#  56630: 'admiralbulldog',
#  56640: 'admiralbulldog',
#  56650: 'admiralbulldog',
#  58380: 'ninja',
#  58390: 'ninja',
#  58400: 'handongsuk',
#  58410: 'ninja',
#  58420: 'ninja',
#  58430: 'handongsuk',
#  58440: 'ninja',
#  58450: 'faker',
#  58460: 'faker',
#  58470: 'faker',
#  59750: 'handongsuk',
#  59760: 'handongsuk',
#  59770: 'handongsuk',
#  59780: 'handongsuk',
#  59790: 'handongsuk',
#  59980: 'faker',
#  60010: 'faker',
#  60020: 'faker',
#  60030: 'faker',
#  60040: 'faker',
#  60050: 'faker',
#  60060: 'hardgamechannel',
#  60070: 'ninja',
#  60110: 'sodapoppin',
#  59880: 'ninja',
#  59890: 'ninja',
#  59900: 'ninja',
#  59910: 'ninja',
#  59920: 'ninja',
#  59930: 'ninja',
#  59940: 'ninja',
#  59950: 'ninja',
#  59960: 'faker',
#  59970: 'faker',
#  60180: 'asmongold',
#  60190: 'asmongold',
#  40140: 'ninja',
#  40150: 'ninja',
#  40160: 'ninja',
#  40170: 'ninja',
#  40180: 'ninja',
#  41390: 'ninja',
#  41400: 'ninja',
#  41410: 'ninja',
#  41420: 'ninja',
#  41430: 'ninja',
#  41440: 'ninja',
#  41450: 'ninja',
#  41460: 'ninja',
#  41470: 'ninja',
#  41480: 'ninja',
#  41490: 'ninja',
#  41500: 'ninja',
#  41510: 'ninja',
#  41520: 'asmongold',
#  41530: 'asmongold',
#  42930: 'asmongold',
#  42940: 'domingo',
#  50070: 'ninja',
#  50080: 'ninja',
#  26140: 'overwatchleague',
#  26150: 'overwatchleague',
#  27810: 'tsm_hamlinz',
#  27820: 'tsm_hamlinz',
#  27830: 'tsm_hamlinz',
#  40680: 'tsm_hamlinz',
#  40690: 'tsm_hamlinz',
#  40700: 'tsm_hamlinz',
#  40710: 'tsm_hamlinz',
#  40720: 'tsm_hamlinz',
#  47630: 'tekken',
#  47640: 'tekken',
#  47550: 'tfue',
#  47560: 'tfue',
#  47610: 'tfue',
#  47620: 'tfue',
#  47910: 'shroud',
#  47920: 'shroud',
#  47930: 'tsm_hamlinz',
#  47940: 'esfandtv',
#  49090: 'tfue',
#  49100: 'tfue',
#  50130: 'ninja',
#  50140: 'ninja',
#  50150: 'ninja',
#  53520: 'criticalrole',
#  53530: 'criticalrole',
#  53540: 'criticalrole',
#  53550: 'criticalrole',
#  54470: 'nickmercs',
#  54480: 'ninja',
#  55110: 'shroud',
#  55120: 'shroud',
#  59330: 'tfue',
#  59340: 'tfue',
#  59800: 'handongsuk',
#  59810: 'thijs',
#  59820: 'ninja',
#  60170: 'asmongold',
#  60200: 'asmongold',
#  60210: 'asmongold',
#  60710: 'tsm_hamlinz',
#  60720: 'tsm_hamlinz',
#  60730: 'tsm_hamlinz',
#  60740: 'tsm_hamlinz',
#  60750: 'tsm_hamlinz',
#  60760: 'tsm_hamlinz',
#  60770: 'tsm_hamlinz',
#  11000: 'riotgames',
#  11010: 'esl_csgob',
#  11020: 'riotgames',
#  11030: 'riotgames',
#  16740: 'charming_jo',
#  16750: 'riotgames',
#  16760: 'riotgames',
#  25310: 'riotgames',
#  25320: 'riotgames',
#  29680: 'riotgames',
#  29690: 'riotgames',
#  29670: 'riotgames',
#  32540: 'dakotaz',
#  32550: 'dakotaz',
#  44160: 'ninja',
#  44170: 'ninja',
#  54100: 'ninja',
#  54110: 'ninja',
#  54460: 'nickmercs',
#  6150: 'nickmercs',
#  6160: 'playhearthstone',
#  13460: 'tfue',
#  36250: 'nickmercs',
#  36260: 'nickmercs',
#  36270: 'nickmercs',
#  36280: 'nickmercs',
#  38960: 'ninja',
#  38970: 'ninja',
#  41980: 'asmongold',
#  41990: 'asmongold',
#  43420: 'criticalrole',
#  43430: 'criticalrole',
#  43440: 'criticalrole',
#  43450: 'criticalrole',
#  43460: 'criticalrole',
#  43470: 'criticalrole',
#  43480: 'criticalrole',
#  49140: 'shroud',
#  49150: 'tsm_myth',
#  49160: 'tsm_myth',
#  49170: 'tsm_myth',
#  49180: 'shroud',
#  49190: 'tsm_hamlinz',
#  49200: 'tsm_hamlinz',
#  59120: 'tfue',
#  59130: 'tfue',
#  59140: 'tfue',
#  59150: 'tfue',
#  59160: 'tfue',
#  37700: 'tfue',
#  37710: 'tfue',
#  37510: 'tfue',
#  37520: 'tfue',
#  38680: 'gotaga',
#  38690: 'gotaga',
#  38700: 'gotaga',
#  38710: 'gotaga',
#  38760: 'gotaga',
#  41580: 'asmongold',
#  41590: 'asmongold',
#  41600: 'asmongold',
#  41610: 'asmongold',
#  50220: 'couragejd',
#  50230: 'couragejd',
#  60280: 'asmongold',
#  60290: 'asmongold',
#  60: 'timthetatman',
#  70: 'timthetatman',
#  80: 'esl_csgo',
#  90: 'esl_csgo',
#  100: 'tfue',
#  250: 'tfue',
#  260: 'tfue',
#  220: 'rajjpatel',
#  230: 'tfue',
#  240: 'tfue',
#  1330: 'esl_csgo',
#  1340: 'esl_csgo',
#  1570: 'shroud',
#  1580: 'shroud',
#  1700: 'shroud',
#  2830: 'squeezielive',
#  2840: 'squeezielive',
#  2850: 'ninja',
#  2860: 'ninja',
#  2930: 'ninja',
#  4120: 'ninja',
#  4090: 'ninja',
#  5180: 'playhearthstone',
#  6890: 'playhearthstone',
#  6900: 'ninja',
#  6870: 'playhearthstone',
#  6880: 'playhearthstone',
#  7420: 'tfue',
#  7430: 'tfue',
#  7440: 'tfue',
#  7450: 'tfue',
#  7460: 'tfue',
#  7470: 'tfue',
#  7480: 'tfue',
#  7490: 'tfue',
#  7500: 'tfue',
#  7510: 'tfue',
#  7520: 'shroud',
#  7530: 'shroud',
#  7540: 'tfue',
#  7550: 'tfue',
#  7560: 'shroud',
#  7570: 'tfue',
#  8800: 'ninja',
#  8810: 'ninja',
#  8790: 'ninja',
#  11040: 'riotgames',
#  11680: 'drdisrespect',
#  11690: 'tfue',
#  11700: 'tfue',
#  11710: 'tfue',
#  12340: 'riotgames',
#  12350: 'riotgames',
#  12360: 'riotgames',
#  12440: 'esl_csgo',
#  12450: 'riotgames',
#  12460: 'riotgames',
#  12470: 'riotgames',
#  14580: 'montanablack88',
#  14590: 'ninja',
#  14570: 'montanablack88',
#  14600: 'ninja',
#  14610: 'ninja',
#  14620: 'ninja',
#  14630: 'rajjpatel',
#  14640: 'tfue',
#  16060: 'tfue',
#  16070: 'tfue',
#  16030: 'ninja',
#  16040: 'tfue',
#  17500: 'tfue',
#  17510: 'tfue',
#  18460: 'ninja',
#  18470: 'ninja',
#  18430: 'ninja',
#  18440: 'ninja',
#  18450: 'ninja',
#  19760: 'riotgames',
#  19770: 'riotgames',
#  19780: 'riotgames',
#  20060: 'ninja',
#  20070: 'ninja',
#  19960: 'mdldisney',
#  19970: 'gotaga',
#  19870: 'mdldisney',
#  19880: 'mdldisney',
#  19890: 'ninja',
#  23990: 'riotgames',
#  24000: 'riotgames',
#  24010: 'riotgames',
#  23950: 'riotgames',
#  23960: 'riotgames',
#  23970: 'riotgames',
#  23980: 'riotgames',
#  24160: 'riotgames',
#  24170: 'riotgames',
#  24180: 'riotgames',
#  24310: 'ninja',
#  24320: 'ninja',
#  24380: 'ninja',
#  24390: 'ninja',
#  24570: 'chap',
#  25740: 'ninja',
#  25750: 'ninja',
#  25760: 'ninja',
#  25770: 'ninja',
#  25820: 'overwatchleague',
#  25830: 'overwatchleague',
#  25840: 'overwatchleague',
#  25850: 'overwatchleague',
#  25860: 'overwatchleague',
#  25870: 'overwatchleague',
#  25880: 'overwatchleague',
#  25890: 'ninja',
#  25900: 'ninja',
#  25910: 'ninja',
#  25920: 'ninja',
#  26060: 'overwatchleague',
#  26070: 'overwatchleague',
#  26080: 'overwatchleague',
#  26090: 'overwatchleague',
#  26100: 'overwatchleague',
#  26110: 'overwatchleague',
#  26120: 'overwatchleague',
#  26130: 'overwatchleague',
#  26160: 'overwatchleague',
#  27840: 'summit1g',
#  27850: 'summit1g',
#  27390: 'rocketstreetlive',
#  27400: 'rocketstreetlive',
#  27410: 'shroud',
#  27420: 'shroud',
#  27430: 'shroud',
#  27440: 'shroud',
#  27450: 'shroud',
#  27460: 'shroud',
#  27470: 'nickmercs',
#  27480: 'nickmercs',
#  28660: 'gotaga',
#  ...}
